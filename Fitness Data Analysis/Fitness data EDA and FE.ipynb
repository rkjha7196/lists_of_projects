# %%
import pandas as pd 
from datetime import datetime
df_activities = pd.read_csv(("cardioActivities.csv"), index_col = "Date")
df_activities.head() 
def parse_date_example(date_string):
    try:
        parsed_date = datetime.strptime(date_string, "%Y-%m-%d")
        return parsed_date
    except ValueError:
        print("Invalid date format!")
        return None

parsed_date = parse_date_example("cardioActivities.csv")
print(df_activities.dtypes)
# Out:
# Invalid date format!
# Activity Id                  object
# Type                         object
# Route Name                   object
# Distance (km)               float64
# Duration                     object
# Average Pace                 object
# Average Speed (km/h)        float64
# Calories Burned             float64
# Climb (m)                     int64
# Average Heart Rate (bpm)    float64
# Friend's Tagged             float64
# Notes                        object
# GPX File                     object
# dtype: object

# %%
df_activities = pd.read_csv('cardioActivities.csv', parse_dates=['Date']) # parse the dataype from object to datetime
print(df_activities.dtypes)
# Out:
# Date                        datetime64[ns]
# Activity Id                         object
# Type                                object
# Route Name                          object
# Distance (km)                      float64
# Duration                            object
# Average Pace                        object
# Average Speed (km/h)               float64
# Calories Burned                    float64
# Climb (m)                            int64
# Average Heart Rate (bpm)           float64
# Friend's Tagged                    float64
# Notes                               object
# GPX File                            object
# dtype: object

# %%
df_activities = pd.read_csv("cardioActivities.csv", index_col = "Date")
print(df_activities)
print(df_activities.dtypes)
# Out:
#                                               Activity Id     Type Route Name  \
# Date
# 2018-11-11 14:05:12  c9627fed-14ac-47a2-bed3-2a2630c63c15  Running        NaN
# 2018-11-09 15:02:35  be65818d-a801-4847-a43b-2acdf4dc70e7  Running        NaN
# 2018-11-04 16:05:00  c09b2f92-f855-497c-b624-c196b3ef036c  Running        NaN
# 2018-11-01 14:03:58  bc9b612d-3499-43ff-b82a-9b17b71b8a36  Running        NaN
# 2018-10-27 17:01:36  972567b2-1b0e-437c-9e82-fef8078d6438  Running        NaN
# ...                                                   ...      ...        ...
# 2012-08-28 07:06:57  f5218490-a372-44c8-bb20-de3b91984cbe  Walking        NaN
# 2012-08-24 12:59:42  018f66a7-da5e-4985-a8fe-725a33317c87  Walking        NaN
# 2012-08-24 10:12:16  7acec95a-d63d-435d-837c-7befb352f500  Walking        NaN
# 2012-08-24 08:13:12  f790bdb2-b921-4018-bd39-d59d870c5847  Running        NaN
# 2012-08-22 18:53:54  706d4d6b-767d-40aa-81c9-e5e85a102051  Running        NaN
#
# ...

# %%
df_activities.sample(3)
# Out:
#                                               Activity Id     Type Route Name  \
# Date
# 2013-05-28 07:16:32  8f49ef93-f404-4abe-9925-adf9cd7a330e  Running        NaN
# 2014-03-24 18:56:12  1f2a8c46-872a-4edd-9055-95fcc0457be5  Running        NaN
# 2013-06-15 08:44:27  6ada32e6-e73f-44a2-a4d5-bf6fd194986e  Running        NaN
#
#                      Distance (km) Duration Average Pace  \
# Date
# 2013-05-28 07:16:32           6.50    24:17         3:44
# 2014-03-24 18:56:12           6.32    36:30         5:47
# 2013-06-15 08:44:27           6.37    29:53         4:41
#
#                      Average Speed (km/h)  Calories Burned  Climb (m)  \
# Date
# 2013-05-28 07:16:32                 16.05            361.0         30
# 2014-03-24 18:56:12                 10.39            455.0         36
# 2013-06-15 08:44:27                 12.79            417.0         36
#
#                      Average Heart Rate (bpm)  Friend's Tagged Notes  \
# Date
# ...

# %%
df_activities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 508 entries, 2018-11-11 14:05:12 to 2012-08-22 18:53:54
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Activity Id               508 non-null    object
#  1   Type                      508 non-null    object
#  2   Route Name                1 non-null      object
#  3   Distance (km)             508 non-null    float64
#  4   Duration                  508 non-null    object
#  5   Average Pace              508 non-null    object
#  6   Average Speed (km/h)      508 non-null    float64
#  7   Calories Burned           508 non-null    float64
#  8   Climb (m)                 508 non-null    int64
#  9   Average Heart Rate (bpm)  294 non-null    float64
#  10  Friend's Tagged           0 non-null      float64
#  11  Notes                     231 non-null    object
#  12  GPX File                  504 non-null    object
# ...

# %%
# df_activities.parse_dates("cardioActivities.csv")
# use to detect the NaN & None values and convert the data set into boolean true or false.
null = pd.isnull(df_activities)
null.head()
# Out:
#                      Activity Id   Type  Route Name  Distance (km)  Duration  \
# Date
# 2018-11-11 14:05:12        False  False        True          False     False
# 2018-11-09 15:02:35        False  False        True          False     False
# 2018-11-04 16:05:00        False  False        True          False     False
# 2018-11-01 14:03:58        False  False        True          False     False
# 2018-10-27 17:01:36        False  False        True          False     False
#
#                      Average Pace  Average Speed (km/h)  Calories Burned  \
# Date
# 2018-11-11 14:05:12         False                 False            False
# 2018-11-09 15:02:35         False                 False            False
# 2018-11-04 16:05:00         False                 False            False
# 2018-11-01 14:03:58         False                 False            False
# 2018-10-27 17:01:36         False                 False            False
#
# ...

# %%
# to calculate the total number of mising values.
pd.isnull(df_activities).sum()
# Out:
# Activity Id                   0
# Type                          0
# Route Name                  507
# Distance (km)                 0
# Duration                      0
# Average Pace                  0
# Average Speed (km/h)          0
# Calories Burned               0
# Climb (m)                     0
# Average Heart Rate (bpm)    214
# Friend's Tagged             508
# Notes                       277
# GPX File                      4
# dtype: int64

# %%
[feature for feature in df_activities.columns if df_activities[feature].dtype!= 'O']
# Out:
# ['Distance (km)',
#  'Average Speed (km/h)',
#  'Calories Burned',
#  'Climb (m)',
#  'Average Heart Rate (bpm)',
#  "Friend's Tagged"]

# %%
[feature for feature in df_activities.columns if df_activities[feature].dtype == 'O']
# Out:
# ['Activity Id',
#  'Type',
#  'Route Name',
#  'Duration',
#  'Average Pace',
#  'Notes',
#  'GPX File']

# %%
df_activities.head()
# Out:
#                                               Activity Id     Type Route Name  \
# Date
# 2018-11-11 14:05:12  c9627fed-14ac-47a2-bed3-2a2630c63c15  Running        NaN
# 2018-11-09 15:02:35  be65818d-a801-4847-a43b-2acdf4dc70e7  Running        NaN
# 2018-11-04 16:05:00  c09b2f92-f855-497c-b624-c196b3ef036c  Running        NaN
# 2018-11-01 14:03:58  bc9b612d-3499-43ff-b82a-9b17b71b8a36  Running        NaN
# 2018-10-27 17:01:36  972567b2-1b0e-437c-9e82-fef8078d6438  Running        NaN
#
#                      Distance (km) Duration Average Pace  \
# Date
# 2018-11-11 14:05:12          10.44    58:40         5:37
# 2018-11-09 15:02:35          12.84  1:14:12         5:47
# 2018-11-04 16:05:00          13.01  1:15:16         5:47
# 2018-11-01 14:03:58          12.98  1:14:25         5:44
# 2018-10-27 17:01:36          13.02  1:12:50         5:36
#
#                      Average Speed (km/h)  Calories Burned  Climb (m)  \
# Date
# ...

# %%
df_activities.tail()
# Out:
#                                               Activity Id     Type Route Name  \
# Date
# 2012-08-28 07:06:57  f5218490-a372-44c8-bb20-de3b91984cbe  Walking        NaN
# 2012-08-24 12:59:42  018f66a7-da5e-4985-a8fe-725a33317c87  Walking        NaN
# 2012-08-24 10:12:16  7acec95a-d63d-435d-837c-7befb352f500  Walking        NaN
# 2012-08-24 08:13:12  f790bdb2-b921-4018-bd39-d59d870c5847  Running        NaN
# 2012-08-22 18:53:54  706d4d6b-767d-40aa-81c9-e5e85a102051  Running        NaN
#
#                      Distance (km) Duration Average Pace  \
# Date
# 2012-08-28 07:06:57           1.57    13:39         8:41
# 2012-08-24 12:59:42           1.48    17:56        12:09
# 2012-08-24 10:12:16           1.49    13:43         9:14
# 2012-08-24 08:13:12           3.15    16:00         5:05
# 2012-08-22 18:53:54           5.69    31:08         5:29
#
#                      Average Speed (km/h)  Calories Burned  Climb (m)  \
# Date
# ...

# %%
# how to fill the datas by a paticular word
import numpy as np
missing_vals = ["NA","",None,np.NaN]
missing = df_activities.isin(missing_vals) # detect the missing value
df_activities.mask(missing,"missing").head() # fill the missing value with df.mask()
# Out:
#                                               Activity Id     Type Route Name  \
# Date
# 2018-11-11 14:05:12  c9627fed-14ac-47a2-bed3-2a2630c63c15  Running    missing
# 2018-11-09 15:02:35  be65818d-a801-4847-a43b-2acdf4dc70e7  Running    missing
# 2018-11-04 16:05:00  c09b2f92-f855-497c-b624-c196b3ef036c  Running    missing
# 2018-11-01 14:03:58  bc9b612d-3499-43ff-b82a-9b17b71b8a36  Running    missing
# 2018-10-27 17:01:36  972567b2-1b0e-437c-9e82-fef8078d6438  Running    missing
#
#                      Distance (km) Duration Average Pace  \
# Date
# 2018-11-11 14:05:12          10.44    58:40         5:37
# 2018-11-09 15:02:35          12.84  1:14:12         5:47
# 2018-11-04 16:05:00          13.01  1:15:16         5:47
# 2018-11-01 14:03:58          12.98  1:14:25         5:44
# 2018-10-27 17:01:36          13.02  1:12:50         5:36
#
#                      Average Speed (km/h)  Calories Burned  Climb (m)  \
# Date
# ...

# %%
df_activities.fillna(0).head()
# Out:
#                                               Activity Id     Type Route Name  \
# Date
# 2018-11-11 14:05:12  c9627fed-14ac-47a2-bed3-2a2630c63c15  Running          0
# 2018-11-09 15:02:35  be65818d-a801-4847-a43b-2acdf4dc70e7  Running          0
# 2018-11-04 16:05:00  c09b2f92-f855-497c-b624-c196b3ef036c  Running          0
# 2018-11-01 14:03:58  bc9b612d-3499-43ff-b82a-9b17b71b8a36  Running          0
# 2018-10-27 17:01:36  972567b2-1b0e-437c-9e82-fef8078d6438  Running          0
#
#                      Distance (km) Duration Average Pace  \
# Date
# 2018-11-11 14:05:12          10.44    58:40         5:37
# 2018-11-09 15:02:35          12.84  1:14:12         5:47
# 2018-11-04 16:05:00          13.01  1:15:16         5:47
# 2018-11-01 14:03:58          12.98  1:14:25         5:44
# 2018-10-27 17:01:36          13.02  1:12:50         5:36
#
#                      Average Speed (km/h)  Calories Burned  Climb (m)  \
# Date
# ...

# %%
df_activities.sample(3)
# Out:
#                                               Activity Id     Type Route Name  \
# Date
# 2018-05-09 18:03:20  90b07c52-c7e6-4458-a73f-7278beedde39  Running        NaN
# 2014-11-11 15:50:00  5dd88a5b-a923-4d7b-81fc-ffcb94473cc6  Running        NaN
# 2015-12-27 13:14:59  7c59b1da-9dfd-43df-8170-a0bc4ad2bdb6  Running        NaN
#
#                      Distance (km) Duration Average Pace  \
# Date
# 2018-05-09 18:03:20          12.76  1:08:31         5:22
# 2014-11-11 15:50:00           9.78    49:45         5:05
# 2015-12-27 13:14:59          13.53  1:16:48         5:41
#
#                      Average Speed (km/h)  Calories Burned  Climb (m)  \
# Date
# 2018-05-09 18:03:20                 11.18       892.000000        170
# 2014-11-11 15:50:00                 11.79       655.000000         51
# 2015-12-27 13:14:59                 10.57       921.999999        185
#
#                      Average Heart Rate (bpm)  Friend's Tagged  \
# Date
# ...

# %%
pd.isnull(df_activities).sum()
# Out:
# Activity Id                   0
# Type                          0
# Route Name                  507
# Distance (km)                 0
# Duration                      0
# Average Pace                  0
# Average Speed (km/h)          0
# Calories Burned               0
# Climb (m)                     0
# Average Heart Rate (bpm)    214
# Friend's Tagged             508
# Notes                       277
# GPX File                      4
# dtype: int64

# %%
#Task 4 -
# %matplotlib inline

#Import matplotlib, set style and ignore warning
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
plt.style.use('ggplot')
warnings.filterwarnings(
    action='ignore', module='matplotlib.figure', category=UserWarning,
    message=('This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.')
)

#Prepare data subsetting period from 2013 till 2018
runs_subset_2013_2018 = df_activities['2018':'2013']

#Create, plot and customize in one step
runs_subset_2013_2018.plot(subplots=True,
                           sharex=False,
                           figsize=(16,16),
                           linestyle='none',
                           marker='o',
                           markersize=3,
                          )

#Show plot
plt.show()

# %%
#Task 6 -
#Prepare data
runs_subset_2015_2018 = df_activities['2018':'2015']
runs_distance = runs_subset_2015_2018['Distance (km)']
runs_hr = runs_subset_2015_2018['Average Heart Rate (bpm)']

#Create plot
fig, (ax1, ax2) = plt.subplots(2, sharex=True, figsize=(16, 16))

#Plot and customize first subplot
runs_distance.plot(ax=ax1)
ax1.set(ylabel='Distance (km)', title='Historical data with averages')
ax1.axhline(runs_distance.mean(), color='blue', linewidth=1, linestyle='-.')

#Plot and customize second subplot
runs_hr.plot(ax=ax2, color='brown')
ax2.set(xlabel='Date', ylabel='Average Heart Rate (bpm)')
ax2.axhline(runs_hr.mean(), color='blue', linewidth=1, linestyle='-.')

#Show plot
plt.show()

# %%
cols_to_drop = ['Route Name','Friend\'s Tagged','Notes']
df1 = df_activities.drop(cols_to_drop, axis =1)
df1
# Out:
#                                               Activity Id     Type  \
# Date
# 2018-11-11 14:05:12  c9627fed-14ac-47a2-bed3-2a2630c63c15  Running
# 2018-11-09 15:02:35  be65818d-a801-4847-a43b-2acdf4dc70e7  Running
# 2018-11-04 16:05:00  c09b2f92-f855-497c-b624-c196b3ef036c  Running
# 2018-11-01 14:03:58  bc9b612d-3499-43ff-b82a-9b17b71b8a36  Running
# 2018-10-27 17:01:36  972567b2-1b0e-437c-9e82-fef8078d6438  Running
# ...                                                   ...      ...
# 2012-08-28 07:06:57  f5218490-a372-44c8-bb20-de3b91984cbe  Walking
# 2012-08-24 12:59:42  018f66a7-da5e-4985-a8fe-725a33317c87  Walking
# 2012-08-24 10:12:16  7acec95a-d63d-435d-837c-7befb352f500  Walking
# 2012-08-24 08:13:12  f790bdb2-b921-4018-bd39-d59d870c5847  Running
# 2012-08-22 18:53:54  706d4d6b-767d-40aa-81c9-e5e85a102051  Running
#
#                      Distance (km) Duration Average Pace  \
# Date
# 2018-11-11 14:05:12          10.44    58:40         5:37
# ...

# %%
df1.value_counts('Type')
# Out:
# Type
# Running    459
# Cycling     29
# Walking     18
# Other        2
# dtype: int64

# %%
df1['Type'] = df1['Type'].str.replace('Other','Unicycling')
df1
# Out:
#                                               Activity Id     Type  \
# Date
# 2018-11-11 14:05:12  c9627fed-14ac-47a2-bed3-2a2630c63c15  Running
# 2018-11-09 15:02:35  be65818d-a801-4847-a43b-2acdf4dc70e7  Running
# 2018-11-04 16:05:00  c09b2f92-f855-497c-b624-c196b3ef036c  Running
# 2018-11-01 14:03:58  bc9b612d-3499-43ff-b82a-9b17b71b8a36  Running
# 2018-10-27 17:01:36  972567b2-1b0e-437c-9e82-fef8078d6438  Running
# ...                                                   ...      ...
# 2012-08-28 07:06:57  f5218490-a372-44c8-bb20-de3b91984cbe  Walking
# 2012-08-24 12:59:42  018f66a7-da5e-4985-a8fe-725a33317c87  Walking
# 2012-08-24 10:12:16  7acec95a-d63d-435d-837c-7befb352f500  Walking
# 2012-08-24 08:13:12  f790bdb2-b921-4018-bd39-d59d870c5847  Running
# 2012-08-22 18:53:54  706d4d6b-767d-40aa-81c9-e5e85a102051  Running
#
#                      Distance (km) Duration Average Pace  \
# Date
# 2018-11-11 14:05:12          10.44    58:40         5:37
# ...

# %%
df1.value_counts('Type')
# Out:
# Type
# Running       459
# Cycling        29
# Walking        18
# Unicycling      2
# dtype: int64

# %%
pd.isnull(df1).sum()
# Out:
# Activity Id                   0
# Type                          0
# Distance (km)                 0
# Duration                      0
# Average Pace                  0
# Average Speed (km/h)          0
# Calories Burned               0
# Climb (m)                     0
# Average Heart Rate (bpm)    214
# GPX File                      4
# dtype: int64

# %%
df2 = df1[df1['Average Heart Rate (bpm)'].isnull()]
df2.tail(50)
df1['Average Heart Rate (bpm)_mean'] = df1['Average Heart Rate (bpm)'].fillna(df1['Average Heart Rate (bpm)'].mean())
df1
# Out:
#                                               Activity Id     Type  \
# Date
# 2018-11-11 14:05:12  c9627fed-14ac-47a2-bed3-2a2630c63c15  Running
# 2018-11-09 15:02:35  be65818d-a801-4847-a43b-2acdf4dc70e7  Running
# 2018-11-04 16:05:00  c09b2f92-f855-497c-b624-c196b3ef036c  Running
# 2018-11-01 14:03:58  bc9b612d-3499-43ff-b82a-9b17b71b8a36  Running
# 2018-10-27 17:01:36  972567b2-1b0e-437c-9e82-fef8078d6438  Running
# ...                                                   ...      ...
# 2012-08-28 07:06:57  f5218490-a372-44c8-bb20-de3b91984cbe  Walking
# 2012-08-24 12:59:42  018f66a7-da5e-4985-a8fe-725a33317c87  Walking
# 2012-08-24 10:12:16  7acec95a-d63d-435d-837c-7befb352f500  Walking
# 2012-08-24 08:13:12  f790bdb2-b921-4018-bd39-d59d870c5847  Running
# 2012-08-22 18:53:54  706d4d6b-767d-40aa-81c9-e5e85a102051  Running
#
#                      Distance (km) Duration Average Pace  \
# Date
# 2018-11-11 14:05:12          10.44    58:40         5:37
# ...

# %%
df1_new = df1.head(503)
df1_new
# Out:
#                                               Activity Id     Type  \
# Date
# 2018-11-11 14:05:12  c9627fed-14ac-47a2-bed3-2a2630c63c15  Running
# 2018-11-09 15:02:35  be65818d-a801-4847-a43b-2acdf4dc70e7  Running
# 2018-11-04 16:05:00  c09b2f92-f855-497c-b624-c196b3ef036c  Running
# 2018-11-01 14:03:58  bc9b612d-3499-43ff-b82a-9b17b71b8a36  Running
# 2018-10-27 17:01:36  972567b2-1b0e-437c-9e82-fef8078d6438  Running
# ...                                                   ...      ...
# 2012-09-02 08:41:31  4a9e2e1b-3a98-4630-8a89-3632aea5559a  Running
# 2012-08-30 07:10:21  3067c059-dd1a-4df7-90b7-5e30b9d7e355  Walking
# 2012-08-29 18:19:26  bad065da-c772-4acc-a986-bc60aafa9473  Walking
# 2012-08-29 08:21:43  5c8520ac-6d45-4c1d-b0a9-61e9c689c1fd  Walking
# 2012-08-28 19:43:52  159e2b06-5808-4204-9d86-013132be67af  Walking
#
#                      Distance (km) Duration Average Pace  \
# Date
# 2018-11-11 14:05:12          10.44    58:40         5:37
# ...

# %%
df1_new.drop(['Activity Id','Average Heart Rate (bpm)','GPX File'], axis = 1, inplace = True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_19404\855239981.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1_new.drop(['Activity Id','Average Heart Rate (bpm)','GPX File'], axis = 1, inplace = True)

# %%
df1_new.isnull().sum()
# Out:
# Type                             0
# Distance (km)                    0
# Duration                         0
# Average Pace                     0
# Average Speed (km/h)             0
# Calories Burned                  0
# Climb (m)                        0
# Average Heart Rate (bpm)_mean    0
# dtype: int64

# %%
df1_new.head()
# Out:
#                         Type  Distance (km) Duration Average Pace  \
# Date
# 2018-11-11 14:05:12  Running          10.44    58:40         5:37
# 2018-11-09 15:02:35  Running          12.84  1:14:12         5:47
# 2018-11-04 16:05:00  Running          13.01  1:15:16         5:47
# 2018-11-01 14:03:58  Running          12.98  1:14:25         5:44
# 2018-10-27 17:01:36  Running          13.02  1:12:50         5:36
#
#                      Average Speed (km/h)  Calories Burned  Climb (m)  \
# Date
# 2018-11-11 14:05:12                 10.68            774.0        130
# 2018-11-09 15:02:35                 10.39            954.0        168
# 2018-11-04 16:05:00                 10.37            967.0        171
# 2018-11-01 14:03:58                 10.47            960.0        169
# 2018-10-27 17:01:36                 10.73            967.0        170
#
#                      Average Heart Rate (bpm)_mean
# Date
# 2018-11-11 14:05:12                          159.0
# ...

# %%
sns.boxplot(df1_new['Distance (km)'])
# Out:
# <AxesSubplot: >

# %%
df1_new.groupby('Type').mean()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_19404\2598200068.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1_new.groupby('Type').mean()
#             Distance (km)  Average Speed (km/h)  Calories Burned   Climb (m)  \
# Type
# Cycling         23.468276             19.125172       558.482759  240.551724
# Running         11.412823             11.054858       800.517075  125.227571
# Unicycling      17.225000             16.100000      1119.500000  210.500000
# Walking          1.927333              5.436667       132.866667   21.400000
#
#             Average Heart Rate (bpm)_mean
# Type
# Cycling                        133.635468
# Running                        144.412495
# Unicycling                      85.500000
# Walking                        143.530612

# %%
import seaborn as sns
sns.heatmap(df1_new.corr(), annot = True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_19404\3299475869.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df1_new.corr(), annot = True)
# <AxesSubplot: >

# %%
#for i in df1.columns:
    #sns.histplot(df1[i], kde = True)
#sns.boxplot(x = df1.Average Heart Rate (bpm)_mean, y = df1.Calories Burned)

# %%
#categorical plot
#fig, (ax1, ax2) = plt.subplots(2, sharex=True, figsize=(12, 12))
plt.figure(figsize=(12, 12)) 
sns.catplot(x = 'Climb (m)', y= 'Calories Burned', data = df1_new.head(50), kind ="box")
#fig, ax = plt.subplots(figsize=(12, 12))
plt.show()

# %%
tips = sns.load_dataset('tips')

# Set the figure size
plt.figure(figsize=(12, 12))  # Set width=8 inches and height=6 inches

# Plot the categorical graph using Seaborn
sns.catplot(x='day', y='total_bill', data=tips, kind='bar')

# Display the plot
plt.show()

# %%
# Set the figure size
sns.set(rc={'figure.figsize': (6, 6)})

# Plot your graph
sns.scatterplot(x ='Climb (m)', y = 'Calories Burned', hue = 'Type', data = df1.head(500))
#sns.catplot(x = 'Average Heart Rate (bpm)_mean', y= 'Calories Burned', data = df1.head(500), kind ="box")
# Show the plot
plt.show()
